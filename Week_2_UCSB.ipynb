# %% [markdown]
# ### Printing, Printing

# %%
print(myName)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-601fdc075130> in <module>()
# ----> 1 print(myName)
#
# NameError: name 'myName' is not defined

# %%
myName = 'lee'
myNumber = 42

# %%
print(myName
# Out:
#   File "<ipython-input-12-c754d15c440c>", line 1
#     print(myName
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
print(myName]
# Out:
#   File "<ipython-input-13-2ceb66b349e6>", line 1
#     print(myName]
#                 ^
# SyntaxError: invalid syntax

# %%
print((myNumber)
# Out:
#   File "<ipython-input-14-64da57d54f44>", line 1
#     print((myNumber)
#                     ^
# SyntaxError: unexpected EOF while parsing

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print(myName)
# Out:
# lee

# %%
print(myNumber)
# Out:
# 42

# %%
print('My name is',myName,'and myNumber is', myNumber)
# Out:
# My name is lee and myNumber is 42

# %% [markdown]
# ### Python Tricks -- https://realpython.com/
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Other Python Resources
# $5.00	Mastering Matplotlib 2.x
# 	Benjamin Walter Keller
#
# $5.00	Python Fundamentals
# 	Ryan Marvin, Mark Ng’ang’a, Amos Omondi
#
# $5.00	Hands-On Data Analysis with NumPy and Pandas
# 	Curtis Miller
#
# $5.00	NumPy: Beginner's Guide - Third Edition
# 	Ivan Idris
#
# $5.00	Learning Jupyter 5 - Second Edition
# 	Dan Toomey
#
# $$$	SciPy and NumPy: An Overview for Developers 1st Edition
# 	by Eli Bressert
#
# $$	The Quick Python Book 3rd Edition
# 	by Naomi Ceder
# FREE	 https://www.tutorialspoint.com/python/

# %%
leeList = [1,2,3,4,5]

# %%
print(leeList)
# Out:
# [1, 2, 3, 4, 5]

# %%
leeList2 = [1, "two", 3, 4.0]

# %%
print(leeList2)
# Out:
# [1, 'two', 3, 4.0]

# %% [markdown]
# ### Accessing elements in a List is easy

# %%
print(leeList2[1])
# Out:
# two

# %%
print(leeList2[1:3])
# Out:
# ['two', 3]

# %%
print(leeList2[:3])
# Out:
# [1, 'two', 3]

# %%
print(leeList2[2:3])
# Out:
# [3]

# %%
print(leeList2[1:3])
# Out:
# ['two', 3]

# %%
print(leeList2[-1])
# Out:
# 4.0
